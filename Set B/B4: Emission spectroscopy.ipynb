# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import Data
data_exp = pd.read_csv("A4 Set B - Combined Datasheet.csv")
data_ver = pd.read_csv("csv-export.csv")

# %%
print(data_exp.columns)
Elements = ["Hydrogen", "Nitrogen", "Helium", "Neon"]
# Out:
# Index(['Element', 'Spectral line Rank', 'theta_left', 'theta_right', 'd_theta',
#        'Order', 'lambda_left', 'lambda_right'],
#       dtype='object')

# %%
# sns.pairplot(data_ver)

# %% [markdown]
# ## Experimental Data Analysis

# %%
print(data_exp.columns)
# Out:
# Index(['Element', 'Spectral line Rank', 'theta_left', 'theta_right', 'd_theta',
#        'Order', 'lambda_left', 'lambda_right'],
#       dtype='object')

# %%
# Calculate Uncertainty
data_exp["lambda_unc"] = np.sin(data_exp["d_theta"]*np.pi/180)*((1/100)*(1/1000))*(1000000000)
data_exp["mean_lambda"] = (data_exp["lambda_left"] + data_exp["lambda_right"])/2

# %%
data_exp
# Out:
#      Element  Spectral line Rank  theta_left  theta_right   d_theta  Order  \
# 0   Hydrogen                   1    3.000000     2.250000  0.750000      1
# 1   Hydrogen                   2    2.916667     2.500000  0.416667      1
# 2   Hydrogen                   3    3.916667     3.500000  0.416667      1
# 3   Hydrogen                   1    4.833333     5.250000  0.416667      2
# 4   Hydrogen                   2    5.916667     5.500000  0.416667      2
# 5   Hydrogen                   3    7.916667     7.333333  0.583333      2
# 6     Helium                   1    2.883333     2.216667  0.666667      1
# 7     Helium                   2    2.950000     2.500000  0.450000      1
# 8     Helium                   3    3.000000     2.750000  0.250000      1
# 9     Helium                   4    3.166667     2.916667  0.250000      1
# 10    Helium                   5    3.366667     3.000000  0.366667      1
# 11    Helium                   6    3.500000     3.183333  0.316667      1
# 12    Helium                   7    3.650000     3.383333  0.266667      1
# 13    Helium                   8    3.850000     3.500000  0.350000      1
# 14    Helium                   9    4.000000     3.750000  0.250000      1
# 15  Nitrogen                   1    2.483333     3.083333  0.600000      1
# 16  Nitrogen                   2    2.716667     3.266667  0.550000      1
# 17  Nitrogen                   3    2.933333     3.466667  0.533333      1
# 18  Nitrogen                   4    3.016667     3.266667  0.250000      1
# 19  Nitrogen                   5    3.333333     3.816667  0.483333      1
# 20  Nitrogen                   6    3.450000     3.950000  0.500000      1
# 21  Nitrogen                   7    3.600000     4.183333  0.583333      1
# 22  Nitrogen                   8    3.816667     4.266667  0.450000      1
# 23      Neon                   1    2.666667     2.833333  0.166667      1
# 24      Neon                   2    2.833333     3.116667  0.283333      1
# 25      Neon                   3    3.100000     3.250000  0.150000      1
# 26      Neon                   4    3.216667     3.600000  0.383333      1
# 27      Neon                   5    3.416667     3.666667  0.250000      1
# 28      Neon                   6    3.583333     3.833333  0.250000      1
# 29      Neon                   7    3.666667     4.050000  0.383333      1
# 30       CO2                   1    2.550000     2.916667  0.366667      1
# 31       CO2                   2    2.750000     3.166667  0.416667      1
# 32       CO2                   3    3.000000     3.333333  0.333333      1
# 33       CO2                   4    3.233333     3.600000  0.366667      1
# 34       CO2                   5    3.500000     3.783333  0.283333      1
# 35       CO2                   6    3.666667     3.833333  0.166667      1
# 36       CO2                   7    3.666667     3.916667  0.250000      1
#
#     lambda_left  lambda_right  lambda_unc  mean_lambda
# 0    523.359562    392.598158  130.895956   457.978860
# 1    508.834536    436.193874   72.721411   472.514205
# 2    683.055024    610.485395   72.721411   646.770210
# 3    421.287826    457.508093   72.721411   439.397960
# 4    515.409399    479.228763   72.721411   497.319081
# 5    688.663339    638.208239  101.809114   663.435789
# 6    503.024223    386.784813  116.352658   444.904518
# 7    514.644678    436.193874   78.539009   475.419276
# 8    523.359562    479.781285   43.633093   501.570424
# 9    552.406263    508.834536   43.633093   530.620400
# 10   587.256112    523.359562   63.994969   555.307837
# 11   610.485395    555.310680   55.268478   582.898038
# 12   636.614381    590.159949   46.541945   613.387165
# 13   671.446211    610.485395   61.086144   640.965803
# 14   697.564737    654.031292   43.633093   675.798015
# 15   433.287742    537.883482  104.717841   485.585612
# 16   473.970140    569.832055   95.991635   521.901098
# 17   511.739628    604.678380   93.082883   558.209004
# 18   526.264436    569.832055   43.633093   548.048246
# 19   581.448289    665.641463   84.356580   623.544876
# 20   601.774795    688.859084   87.265355   645.316939
# 21   627.905195    729.480870  101.809114   678.693033
# 22   665.641463    743.985754   78.539009   704.813608
# 23   465.253122    494.308433   29.088780   479.780778
# 24   494.308433    543.692732   49.450794   519.000583
# 25   540.788130    566.927876   26.179909   553.858003
# 26   561.119373    627.905195   66.903789   594.512284
# 27   595.967473    639.517336   43.633093   617.742404
# 28   625.002027    668.543865   43.633093   646.772946
# 29   639.517336    706.269859   66.903789   672.893598
# 30   444.912047    508.834536   63.994969   476.873292
# 31   479.781285    552.406263   72.721411   516.093774
# 32   523.359562    581.448289   58.177314   552.403926
# 33   564.023648    627.905195   63.994969   595.964422
# 34   610.485395    659.836489   49.450794   635.160942
# 35   639.517336    668.543865   29.088780   654.030601
# 36   639.517336    683.055024   43.633093   661.286180

# %%
# filtered_df = df[(df['element'] == 'Hydrogen') & (df['order'] == 1)]

f_exp_by_elements = {}
for E in ["Hydrogen", "Nitrogen", "Helium", "Neon", "CO2"]:
    f_exp_by_elements[f"{E}"] = data_exp[(data_exp["Element"] == E) & (data_exp["Order"] == 1)]

# %%
f_exp_by_elements["CO2"]
# Out:
#    Element  Spectral line Rank  theta_left  theta_right   d_theta  Order  \
# 30     CO2                   1    2.550000     2.916667  0.366667      1
# 31     CO2                   2    2.750000     3.166667  0.416667      1
# 32     CO2                   3    3.000000     3.333333  0.333333      1
# 33     CO2                   4    3.233333     3.600000  0.366667      1
# 34     CO2                   5    3.500000     3.783333  0.283333      1
# 35     CO2                   6    3.666667     3.833333  0.166667      1
# 36     CO2                   7    3.666667     3.916667  0.250000      1
#
#     lambda_left  lambda_right  lambda_unc  mean_lambda
# 30   444.912047    508.834536   63.994969   476.873292
# 31   479.781285    552.406263   72.721411   516.093774
# 32   523.359562    581.448289   58.177314   552.403926
# 33   564.023648    627.905195   63.994969   595.964422
# 34   610.485395    659.836489   49.450794   635.160942
# 35   639.517336    668.543865   29.088780   654.030601
# 36   639.517336    683.055024   43.633093   661.286180

# %% [markdown]
# ## Vernier Data Analysis

# %%
# Plotting Stuff
def plot_spectral(x, y, element):
    sns.set_theme(style="darkgrid")
    plt.figure(figsize=(12, 6))

    sns.lineplot(
        x=x, 
        y=y, 
        label=f"{element} Spectrum", 
        color="blue",
        linewidth=2.5
    )
    plt.xlabel("Wavelength (nm)", fontsize=14)
    plt.ylabel("Intensity", fontsize=14)
    plt.title(f"{element} Spectral Line Data", fontsize=16, fontweight="bold")

    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.6)

    plt.legend(fontsize=12)

    plt.show()
    
def remove_noise(noise_intensity, noise_wavelength, element_intensity, element_wavelength, element):

    element_df = pd.DataFrame({'Wavelength': element_wavelength, f'{element}_Intensity': element_intensity})
    noise_df = pd.DataFrame({'Wavelength': noise_wavelength, 'Noise_Intensity': noise_intensity})

    merged_df = pd.merge(element_df, noise_df, on='Wavelength', how='left').fillna(0)

    merged_df['Corrected_Intensity'] = merged_df[f'{element}_Intensity'] - merged_df['Noise_Intensity']

    merged_df['Corrected_Intensity'] = np.maximum(merged_df['Corrected_Intensity'], 0)

    return merged_df[['Wavelength', 'Corrected_Intensity']]

# %%
# data_ver
# Remove Absorbance
cols_to_drop = [col for col in data_ver.columns if "Absorbance" in col]

# Drop the columns from the DataFrame
data_ver_cleaned = data_ver.drop(columns=cols_to_drop)
print(data_ver_cleaned.columns)
# Out:
# Index(['Hydrogen:Wavelength(nm)', 'Hydrogen:Raw', 'Noise:Wavelength(nm)',
#        'Noise:Raw', 'Nitrogen:Wavelength(nm)', 'Nitrogen:Raw',
#        'Helium:Wavelength(nm)', 'Helium:Raw', 'Mercury:Wavelength(nm)',
#        'Mercury:Raw', 'Neon:Wavelength(nm)', 'Neon:Raw', 'CO2:Wavelength(nm)',
#        'CO2:Raw', 'Data Set 8:Wavelength(nm)', 'Data Set 8:Raw'],
#       dtype='object')

# %%
# Clean Elements by Clipping
Elements = ["Hydrogen", "Nitrogen", "Helium", "Neon", "CO2"]
cleaned_elements = {}
for E in Elements:
    cleaned_elements[f"{E}"] = remove_noise(data_ver_cleaned["Noise:Raw"], data_ver_cleaned["Noise:Wavelength(nm)"], data_ver_cleaned[f"{E}:Raw"], data_ver_cleaned[f"{E}:Wavelength(nm)"], E)

# %%
# Clean Elements by gaussian filter
from scipy.ndimage import gaussian_filter1d

def remove_noise_g(data, column, sigma=1):

    df = data.copy()

    df[column] = gaussian_filter1d(df[column], sigma=sigma)
    
    return df

# %%
Vernier_Data = {}
for E in Elements:
    Vernier_Data[f"{E}"] = remove_noise_g(cleaned_elements[f"{E}"], "Corrected_Intensity", 10)

# %%
print(Vernier_Data["Hydrogen"])
# Out:
#      Wavelength  Corrected_Intensity
# 0         380.6            24.586381
# 1         381.4            24.657194
# 2         382.3            24.797415
# 3         383.2            25.005179
# 4         384.0            25.276892
# ..          ...                  ...
# 639       896.5             0.145040
# 640       897.4             0.136980
# 641       898.2             0.130773
# 642       899.1             0.126556
# 643       900.0             0.124419
#
# [644 rows x 2 columns]

# %%
# Plot Spectral lines
for E in Elements:
    plot_spectral(Vernier_Data[f"{E}"]["Wavelength"], Vernier_Data[f"{E}"]["Corrected_Intensity"], E)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def get_local_peaks(data, column, prominence=0.1, distance=5):
    df = data.copy()
    peaks, _ = find_peaks(df[column], prominence=prominence, distance=distance)
    df["Peaks"] = 0
    df.loc[peaks, "Peaks"] = 1  # Mark peaks in the DataFrame
    return df, peaks
df_Vernier = {}
for E in Elements:
    clean_df, peak_indices = get_local_peaks(Vernier_Data[f"{E}"], column="Corrected_Intensity", prominence=34, distance=5)
    df_Vernier[f"{E}"] = clean_df[clean_df["Peaks"] == 1]
#     print(clean_df)
    # Plot results
    plt.figure(figsize=(8, 4))
    plt.plot(clean_df["Wavelength"], clean_df["Corrected_Intensity"], label="Corrected_Intensity")

    # Add vertical lines at peak positions with labels
    for peak in peak_indices:
        wavelength = clean_df["Wavelength"].iloc[peak]
        plt.axvline(x=wavelength, color='red', linestyle='--', alpha=0.7, label = wavelength)
#         plt.text(wavelength, max(clean_df["Corrected_Intensity"]) * 0.9, f"{wavelength:.2f}", rotation=90, verticalalignment='bottom', color='red')

    plt.xlabel("Wavelength (nm)")
    plt.ylabel("Intensity")
    plt.legend()
    plt.show()

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from scipy.signal import find_peaks

# def get_local_peaks(data, column, prominence=0.1, distance=5):

#     df = data.copy()
#     peaks, _ = find_peaks(df[column], prominence=prominence, distance=distance)

#     df["Peaks"] = 0
#     df.loc[peaks, "Peaks"] = 1  # Mark peaks in the DataFrame

#     return df, peaks

# for E in Elements:
#     clean_df, peak_indices = get_local_peaks(Vernier_Data[f"{E}"], column="Corrected_Intensity", prominence=34, distance=5)

#     # Plot results
#     plt.figure(figsize=(8, 4))
#     plt.plot(clean_df["Wavelength"], clean_df["Corrected_Intensity"], label="Corrected_Intensity")
#     plt.scatter(clean_df["Wavelength"].iloc[peak_indices], clean_df["Corrected_Intensity"].iloc[peak_indices], 
#                 color='red', label="Peaks", zorder=3)
#     plt.xlabel("Wavelength (nm)")
#     plt.ylabel("Intensity")
#     plt.legend()
#     plt.show()

# %%
# # Plot Spectral lines
# for E in Elements:
#     find_and_plot_peaks(bands[f"{E[0]}"], cleaned_elements[f"{E}"]["Wavelength"], cleaned_elements[f"{E}"]["Corrected_Intensity"], E, f_exp_by_elements[f"{E}"]["mean_lambda"], f_exp_by_elements[f"{E}"]["lambda_unc"])

# %% [markdown]
# ## Retrieve Data from NIST

# %%
import requests
from bs4 import BeautifulSoup
import io
# site = "https://physics.nist.gov/cgi-bin/ASD/lines1.pl?spectra={}" \
#                "&limits_type=0&low_w={}" \
#                "&upp_w={}" \
#                "&unit=1&submit=Retrieve+Data&de=0&format=3&line_out=0&remove_js=on&en_unit=0&output=0&bibrefs=1&page_size=15&show_obs_wl=1&show_calc_wl=1&unc_out=1&order_out=0&max_low_enrg=&show_av=2&max_upp_enrg=&tsb_value=0&min_str=&A_out=1&intens_out=on&max_str=&allowed_out=1&forbid_out=1&min_accur=&min_intens=&conf_out=on&term_out=on&enrg_out=on&J_out=on"

# %%
# Load all Data
NIST_data = {}
for element in ["He", "H", "N", "Ne", "CO2", "C", "O", "CO"]:
    site = "https://physics.nist.gov/cgi-bin/ASD/lines1.pl?spectra={}" \
               "&limits_type=0&low_w={}" \
               "&upp_w={}" \
               "&unit=1&submit=Retrieve+Data&de=0&format=3&line_out=0&remove_js=on&en_unit=0&output=0&bibrefs=1&page_size=15&show_obs_wl=1&show_calc_wl=1&unc_out=1&order_out=0&max_low_enrg=&show_av=2&max_upp_enrg=&tsb_value=0&min_str=&A_out=1&intens_out=on&max_str=&allowed_out=1&forbid_out=1&min_accur=&min_intens=&conf_out=on&term_out=on&enrg_out=on&J_out=on"
    site = site.format(element, 200, 780)
    respond = requests.get(site)
    soup = BeautifulSoup(respond.content, 'lxml')
    html_data = soup.get_text()
    html_data = html_data.replace('"', "")
    data = io.StringIO(html_data)
    NIST_data[f"{element}"] = pd.read_csv(data, sep="\t")

# %%
import re

def clean_intensity(value):
    if isinstance(value, str):  
        # Extract the first valid number (including decimals)
        match = re.search(r'\d+(\.\d+)?', value)
        if match:
            value = match.group(0)  # Get the matched number
        else:
            return None  # Return None if no number is found
    return pd.to_numeric(value, errors='coerce')  # Convert to number, NaN if invalid

for element in ["H", "He", "N", "Ne", "CO2", "C", "O", "CO"]:
    NIST_data[f"{element}"] = NIST_data[f"{element}"].dropna(subset=['obs_wl_air(nm)'])
    NIST_data[f"{element}"] = NIST_data[f"{element}"].dropna(subset=['intens'])
    NIST_data[f"{element}"]["intens"] = NIST_data[f"{element}"]["intens"].apply(clean_intensity)
    if element in ["N", "Ne"]:
        if element == "Ne":
            NIST_data[f"{element}"] = NIST_data[f"{element}"][(NIST_data[f"{element}"]["intens"] < 20000)]
        unique_sp_nums = NIST_data[f"{element}"]["sp_num"].unique()
        print(unique_sp_nums)
        for sp in unique_sp_nums:
            NIST_data[f"{element}_{sp}"] = NIST_data[f"{element}"][(NIST_data[f"{element}"]["sp_num"] == sp)]
# Out:
# [3 4 2 5 1]
# [5 3 2 8 4 6 7 1]

# %%
# NIST_data

# %%
df_Vernier["Hydrogen"]
# Out:
#      Wavelength  Corrected_Intensity  Peaks
# 54        426.9           135.163876      1
# 117       480.9           623.958496      1
# 340       656.1          4510.669792      1

# %%
# Find Theo
def find_theo(df_exp, df_theo, column):
    df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])

small_Elements = ["H", "N", "He", "Ne", "CO2"]
for i, element in enumerate(["Hydrogen", "Nitrogen", "Helium", "Neon", "CO2"]):
    find_theo(f_exp_by_elements[f"{element}"], NIST_data[f"{small_Elements[i]}"], "mean_lambda")
    find_theo(df_Vernier[f"{element}"], NIST_data[f"{small_Elements[i]}"], "Wavelength")
# Out:
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])
# /tmp/ipykernel_51157/3112720499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp["theo_lambda"] = df_exp[f"{column}"].apply(lambda x: df_theo.iloc[(df_theo["obs_wl_air(nm)"] - x).abs().argmin()]['obs_wl_air(nm)'])

# %%
# f_exp_by_elements["Hydrogen"]

# %%
# f_exp_by_elements["Nitrogen"]

# %%
# f_exp_by_elements["Helium"]

# %%
# f_exp_by_elements["Neon"]
df_Vernier["Hydrogen"]
# Out:
#      Wavelength  Corrected_Intensity  Peaks  theo_lambda
# 54        426.9           135.163876      1     434.0472
# 117       480.9           623.958496      1     486.1350
# 340       656.1          4510.669792      1     656.2790

# %%
# Find Error 
for elements in ["Hydrogen", "Nitrogen", "Helium", "Neon", "CO2"]:
    f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
    df_Vernier[f"{elements}"]["Error (%)"] = 100*np.abs(df_Vernier[f"{elements}"]["Wavelength"] - df_Vernier[f"{elements}"]["theo_lambda"])/df_Vernier[f"{elements}"]["theo_lambda"]
# Out:
# /tmp/ipykernel_51157/22832498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
# /tmp/ipykernel_51157/22832498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
# /tmp/ipykernel_51157/22832498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
# /tmp/ipykernel_51157/22832498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
# /tmp/ipykernel_51157/22832498.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_exp_by_elements[f"{elements}"]["Error (%)"] = 100*np.abs(f_exp_by_elements[f"{elements}"]["mean_lambda"] - f_exp_by_elements[f"{elements}"]["theo_lambda"])/f_exp_by_elements[f"{elements}"]["theo_lambda"]
# /tmp/ipykernel_51157/22832498.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Vernier[f"{elements}"]["Error (%)"] = 100*np.abs(df_Vernier[f"{elements}"]["Wavelength"] - df_Vernier[f"{elements}"]["theo_lambda"])/df_Vernier[f"{elements}"]["theo_lambda"]

# %%
df_Vernier["Hydrogen"]
# Out:
#      Wavelength  Corrected_Intensity  Peaks  theo_lambda  Error (%)
# 54        426.9           135.163876      1     434.0472   1.646641
# 117       480.9           623.958496      1     486.1350   1.076861
# 340       656.1          4510.669792      1     656.2790   0.027275

# %%
# df_Vernier["Helium"]["Error (%)"].mean()
df_Vernier["Helium"]
# Out:
#      Wavelength  Corrected_Intensity  Peaks  theo_lambda  Error (%)
# 136       497.1            88.757422      1    501.56783   0.890773
# 249       587.7           124.328651      1    587.56210   0.023470
# 356       668.1            69.561813      1    667.81510   0.042662
# 406       706.0            60.972513      1    706.51900   0.073459
# 496       777.6           118.037185      1    728.13490   6.793398

# %%
df_Vernier["Nitrogen"]
# df_Vernier["Nitrogen"]["Error (%)"].mean()
# Out:
# 0.417137156613575

# %%
df_Vernier["Neon"]
# df_Vernier["Neon"]["Error (%)"].mean()
# Out:
# 0.1950254107301604

# %%
df_Vernier["CO2"]
# Out:
#      Wavelength  Corrected_Intensity  Peaks  theo_lambda  Error (%)
# 116       480.0           297.007293      1      378.231  26.906573

# %%
f_exp_by_elements["Hydrogen"]
# bands["Hydrogen"] = []
# Out:
#     Element  Spectral line Rank  theta_left  theta_right   d_theta  Order  \
# 0  Hydrogen                   1    3.000000         2.25  0.750000      1
# 1  Hydrogen                   2    2.916667         2.50  0.416667      1
# 2  Hydrogen                   3    3.916667         3.50  0.416667      1
#
#    lambda_left  lambda_right  lambda_unc  mean_lambda  theo_lambda  Error (%)
# 0   523.359562    392.598158  130.895956   457.978860     434.0472   5.513608
# 1   508.834536    436.193874   72.721411   472.514205     486.1350   2.801854
# 2   683.055024    610.485395   72.721411   646.770210     656.2790   1.448895

# %%
f_exp_by_elements["Helium"]
# print(f_exp_by_elements["Helium"]["Error (%)"].mean())
# Out:
# 2.460591067046437

# %%
f_exp_by_elements["Nitrogen"]
# print(f_exp_by_elements["Nitrogen"]["Error (%)"].mean())
# Out:
# 1.1587351638438688

# %%
f_exp_by_elements["Neon"]
# print(f_exp_by_elements["Neon"]["Error (%)"].mean())
# Out:
# 0.081378935186089

# %%
f_exp_by_elements["CO2"]
# Out:
#    Element  Spectral line Rank  theta_left  theta_right   d_theta  Order  \
# 30     CO2                   1    2.550000     2.916667  0.366667      1
# 31     CO2                   2    2.750000     3.166667  0.416667      1
# 32     CO2                   3    3.000000     3.333333  0.333333      1
# 33     CO2                   4    3.233333     3.600000  0.366667      1
# 34     CO2                   5    3.500000     3.783333  0.283333      1
# 35     CO2                   6    3.666667     3.833333  0.166667      1
# 36     CO2                   7    3.666667     3.916667  0.250000      1
#
#     lambda_left  lambda_right  lambda_unc  mean_lambda  theo_lambda  Error (%)
# 30   444.912047    508.834536   63.994969   476.873292      378.231  26.079907
# 31   479.781285    552.406263   72.721411   516.093774      378.231  36.449359
# 32   523.359562    581.448289   58.177314   552.403926      378.231  46.049352
# 33   564.023648    627.905195   63.994969   595.964422      378.231  57.566255
# 34   610.485395    659.836489   49.450794   635.160942      378.231  67.929372
# 35   639.517336    668.543865   29.088780   654.030601      378.231  72.918296
# 36   639.517336    683.055024   43.633093   661.286180      378.231  74.836589

# %%
# Theoretical Number of Spectral Lines vs Experimental
for elements in Elements:
    print(f"{elements}")
    print(f" Theoretical {f_exp_by_elements[f"{elements}"]["theo_lambda"].nunique()}, Experimental {len(f_exp_by_elements[f"{elements}"]["Spectral line Rank"])}")
# Out:
# Hydrogen
#  Theoretical 3, Experimental 3
# Nitrogen
#  Theoretical 7, Experimental 8
# Helium
#  Theoretical 6, Experimental 9
# Neon
#  Theoretical 7, Experimental 7
# CO2
#  Theoretical 1, Experimental 7

# %%
def wavelength_to_rgb(wavelength, intensity=1.0):

    gamma = 0.8
    intensity = np.clip(intensity, 0, 1)  
    R = G = B = 0

    if 380 <= wavelength < 440:
        R = -(wavelength - 440) / (440 - 380)
        G = 0.0
        B = 1.0
    elif 440 <= wavelength < 490:
        R = 0.0
        G = (wavelength - 440) / (490 - 440)
        B = 1.0
    elif 490 <= wavelength < 510:
        R = 0.0
        G = 1.0
        B = -(wavelength - 510) / (510 - 490)
    elif 510 <= wavelength < 580:
        R = (wavelength - 510) / (580 - 510)
        G = 1.0
        B = 0.0
    elif 580 <= wavelength < 645:
        R = 1.0
        G = -(wavelength - 645) / (645 - 580)
        B = 0.0
    elif 645 <= wavelength < 780:
        R = 1.0
        G = 0.0
        B = 0.0

    R = ((R * intensity) ** gamma)
    G = ((G * intensity) ** gamma)
    B = ((B * intensity) ** gamma)

    return (R, G, B)

def normalize_intensities(intensities):

    min_intensity = np.min(intensities)
    max_intensity = np.max(intensities)
    if max_intensity == min_intensity:  # Avoid division by zero
        return np.ones_like(intensities)
    
    normalized = (intensities - min_intensity) / (max_intensity - min_intensity)
#     normalized[normalized < 0.99] = 0  # Set values below 50% to 0
    return normalized

def plot_spectral_lines(wavelengths, intensities=None, title = None, fig = None, ax = None):

    wavelengths = np.array(wavelengths)  # Convert to numpy array
    
    if intensities is None:
        intensities = np.ones_like(wavelengths)  # Default to full brightness
    else:
#         intensities = np.array(intensities)
        intensities = normalize_intensities(intensities)
#         plt.plot(intensities, label = title)
#         plt.legend()

#     fig, ax = plt.subplots(figsize=(15, 2))
    
    ax.set_xlim(380, 780)
    ax.set_ylim(0, 1)
    ax.set_xticks(np.arange(400, 800, 50))
    ax.set_yticks([])  # Hide y-axis
#     print(intensities)
    for wavelength, intensity in zip(wavelengths, intensities):
        if 380 <= wavelength <= 780:
            color = wavelength_to_rgb(wavelength, intensity)
            ax.axvline(wavelength, color=color, linewidth=2)

    ax.set_facecolor('black')  # Background color
    ax.grid(False)
    ax.set_title(title, fontsize=14, pad=10)
#     plt.title("")
#     plt.show()

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 6))
plot_spectral_lines(NIST_data["H"]["obs_wl_air(nm)"], NIST_data["H"]["intens"], title = "NIST Data (Hydrogen)", fig = fig, ax = axes[0]) 
plot_spectral_lines(f_exp_by_elements["Hydrogen"]["mean_lambda"], title = "Experimental Data (Hydrogen)", fig = fig, ax = axes[1]) 
plot_spectral_lines(Vernier_Data["Hydrogen"]["Wavelength"], Vernier_Data[f"Hydrogen"]["Corrected_Intensity"], title = "Vernier Data (Hydrogen)", fig = fig, ax = axes[2])
# Adjust layout
plt.tight_layout()
plt.savefig("Hydrogen.pdf")
plt.show()

# %%
e = "Helium"
fig, axes = plt.subplots(3, 1, figsize=(12, 6))
plot_spectral_lines(NIST_data["He"]["obs_wl_air(nm)"], NIST_data["He"]["intens"], title = f"NIST Data ({e})", fig = fig, ax = axes[0])  # Hydrogen spectral lines
plot_spectral_lines(f_exp_by_elements[f"{e}"]["mean_lambda"], title = f"Experimental Data ({e})", fig = fig, ax = axes[1]) 
plot_spectral_lines(Vernier_Data[f"{e}"]["Wavelength"], Vernier_Data[f"{e}"]["Corrected_Intensity"], title =f"Vernier Data ({e})", fig = fig, ax = axes[2])
# Adjust layout
plt.tight_layout()
plt.savefig("Helium.pdf")
plt.show()

# %%
e = "Nitrogen"
# Plot NIST
# Total

unique_sp_nums = NIST_data[f"N"]["sp_num"].unique()
unique_sp_nums.sort()
fig, axes = plt.subplots(len(unique_sp_nums) + 3, 1, figsize=(12, (len(unique_sp_nums) + 3)*2))
for i, sp in enumerate(unique_sp_nums):
    plot_spectral_lines(NIST_data[f"N_{sp}"]["obs_wl_air(nm)"],NIST_data[f"N_{sp}"]["intens"], title = f"NIST Data ({e} {sp*"I"})", fig = fig, ax = axes[i])  # Hydrogen spectral lines
plot_spectral_lines(NIST_data[f"N"]["obs_wl_air(nm)"],NIST_data[f"N"]["intens"], title = f"NIST Data (All {e})", fig = fig, ax = axes[len(unique_sp_nums)])
plot_spectral_lines(f_exp_by_elements[f"{e}"]["mean_lambda"], title = f"Experimental Data ({e})", fig = fig, ax = axes[len(unique_sp_nums) + 1]) 
plot_spectral_lines(Vernier_Data[f"{e}"]["Wavelength"], Vernier_Data[f"{e}"]["Corrected_Intensity"], title =f"Vernier Data ({e})", fig = fig, ax = axes[len(unique_sp_nums) + 2])
                         
plt.tight_layout()
plt.savefig("Nitrogen_Appendix.pdf")
plt.show()

# %%
e = "Nitrogen"
# Plot NIST
# Total

df_combined = pd.concat([NIST_data[f"N_1"], NIST_data[f"N_2"]], ignore_index=True)
fig, axes = plt.subplots(3, 1, figsize=(12, 6))
plot_spectral_lines(df_combined["obs_wl_air(nm)"], df_combined["intens"], title = f"NIST Data ({e} I and II)", fig = fig, ax = axes[0])  # Hydrogen spectral lines
# plot_spectral_lines(NIST_data[f"N"]["obs_wl_air(nm)"],NIST_data[f"N"]["intens"], title = f"NIST Data (All {e})", fig = fig, ax = axes[1])
plot_spectral_lines(f_exp_by_elements[f"{e}"]["mean_lambda"], title = f"Experimental Data ({e})", fig = fig, ax = axes[1]) 
plot_spectral_lines(Vernier_Data[f"{e}"]["Wavelength"], Vernier_Data[f"{e}"]["Corrected_Intensity"], title =f"Vernier Data ({e})", fig = fig, ax = axes[2])
                         
plt.tight_layout()
plt.savefig("Nitrogen.pdf")
plt.show()

# %%
e = "Neon"


unique_sp_nums = NIST_data[f"Ne"]["sp_num"].unique()
unique_sp_nums.sort()
# unique_sp_nums = [1, 2, 3, 8]
fig, axes = plt.subplots(len(unique_sp_nums) + 3, 1, figsize=(12, (len(unique_sp_nums) + 3)*2))
for i, sp in enumerate(unique_sp_nums):
    plot_spectral_lines(NIST_data[f"Ne_{sp}"]["obs_wl_air(nm)"], NIST_data[f"Ne_{sp}"]["intens"], title = f"NIST Data ({e} {sp*"I"})", fig = fig, ax = axes[i])  

plot_spectral_lines(NIST_data[f"Ne"]["obs_wl_air(nm)"], NIST_data[f"Ne"]["intens"], title = f"NIST Data ({e})", fig = fig, ax = axes[len(unique_sp_nums)])
plot_spectral_lines(f_exp_by_elements[f"{e}"]["mean_lambda"], title = f"Experimental Data ({e})", fig = fig, ax = axes[len(unique_sp_nums) + 1])
plot_spectral_lines(Vernier_Data[f"{e}"]["Wavelength"], Vernier_Data[f"{e}"]["Corrected_Intensity"], title =f"Vernier Data ({e})", fig = fig, ax = axes[len(unique_sp_nums)+2])

plt.tight_layout()
plt.savefig("Neon_Appendix.pdf")
plt.show()

# %%
e = "Neon"


unique_sp_nums = NIST_data[f"Ne"]["sp_num"].unique()
unique_sp_nums.sort()
fig, axes = plt.subplots(3, 1, figsize=(12, 6))
for i, sp in enumerate(unique_sp_nums):
    if sp == 1:
        plot_spectral_lines(NIST_data[f"Ne_{sp}"]["obs_wl_air(nm)"], NIST_data[f"Ne_{sp}"]["intens"], title = f"NIST Data ({e} {sp*"I"})", fig = fig, ax = axes[0])  

# plot_spectral_lines(NIST_data[f"Ne"]["obs_wl_air(nm)"], NIST_data[f"Ne"]["intens"], title = f"NIST Data ({e})", fig = fig, ax = axes[len(unique_sp_nums)])
plot_spectral_lines(f_exp_by_elements[f"{e}"]["mean_lambda"], title = f"Experimental Data ({e})", fig = fig, ax = axes[1])
plot_spectral_lines(Vernier_Data[f"{e}"]["Wavelength"], Vernier_Data[f"{e}"]["Corrected_Intensity"], title =f"Vernier Data ({e})", fig = fig, ax = axes[2])

plt.tight_layout()
plt.savefig("Neon.pdf")
plt.show()

# %%
# data = NIST_data["CO"]["intens"]
# plt.scatter([i for i in range(len(data))] , data)

# %%
# Screen some bad stuff
NIST_data["C"] = NIST_data["C"][NIST_data["C"]["intens"] <  5]
NIST_data["O"] = NIST_data["O"][NIST_data["O"]["intens"] <  100]
NIST_data["CO"] = NIST_data["CO"][NIST_data["CO"]["intens"] <  100]
# NIST_data["CO"]["intens_log"] = np.log(NIST_data["CO"]["intens"].replace(0, np.nan))  # Replace 0 with NaN to avoid errors

# %%
fig, axes = plt.subplots(5, 1, figsize=(12, 10))
# plot_spectral_lines(NIST_data["CO2"]["obs_wl_air(nm)"], NIST_data["CO2"]["intens"], title = "NIST Data (CO2)", fig = fig, ax = axes[0]) 
plot_spectral_lines(NIST_data["C"]["obs_wl_air(nm)"], NIST_data["C"]["intens"], title = "NIST Data (C)", fig = fig, ax = axes[0]) 
plot_spectral_lines(NIST_data["O"]["obs_wl_air(nm)"], NIST_data["O"]["intens"], title = "NIST Data (O)", fig = fig, ax = axes[1]) 
plot_spectral_lines(NIST_data["CO"]["obs_wl_air(nm)"], NIST_data["CO"]["intens"], title = "NIST Data (CO)", fig = fig, ax = axes[2]) 
plot_spectral_lines(f_exp_by_elements["CO2"]["mean_lambda"], title = "Experimental Data (CO2)", fig = fig, ax = axes[3]) 
plot_spectral_lines(Vernier_Data["CO2"]["Wavelength"], Vernier_Data[f"CO2"]["Corrected_Intensity"], title = "Vernier Data (CO2)", fig = fig, ax = axes[4])
# Adjust layout
plt.tight_layout()
plt.savefig("CO2.pdf")
plt.show()
